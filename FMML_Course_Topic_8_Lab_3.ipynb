# %% [markdown]
# <a href="https://colab.research.google.com/github/Samplerbhavanigithub/FMML-2023_PROJECTS_AND_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 08:40:25--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   214MB/s    in 0.3s
#
# 2024-03-31 08:40:25 (214 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5453    1406.0167v3  We give two provably accurate feature-selectio...  stat
# 18446   1009.5290v1  The problem of measuring similarity of graphs ...    cs
# 12225  1710.08167v1  Visual exploration of high-dimensional real-va...  stat
# 7771   1803.02781v1  Many real world problems can now be effectivel...  stat
# 13681  1612.03707v1  The standard LSTM, although it succeeds in the...    cs
# ...             ...                                                ...   ...
# 21057  1707.03336v1  We propose and evaluate a new technique for le...    cs
# 18297   0805.3802v1  In the last year more than 70,000 people have ...    cs
# 26183  1609.01828v1  In this work, we propose a Triangle based appr...    cs
# 22367  1603.07738v1  Multiplayer Online Battle Arena (MOBA) games a...  stat
# 19102   1304.1111v1  In this paper, optimum decomposition of belief...    cs
#
#                                                    title  year  \
# 5453   Feature Selection for Linear SVM with Provable...  2014
# 18446  Measuring Similarity of Graphs and their Nodes...  2010
# 12225  Interactive Visual Data Exploration with Subje...  2017
# 7771                                    Fast Dawid-Skene  2018
# 13681  Empirical Evaluation of A New Approach to Simp...  2016
# ...                                                  ...   ...
# 21057  CHARDA: Causal Hybrid Automata Recovery via Dy...  2017
# 18297  Feature Selection for Bayesian Evaluation of T...  2008
# 26183  Delaunay Triangulation on Skeleton of Flowers ...  2016
# 22367  Skill-Based Differences in Spatio-Temporal Tea...  2016
# 19102           Optimal Decomposition of Belief Networks  2013
#
#                                                 keywords
# 5453   [selection, techniques, algorithms, determinis...
# 18446  [measuring, similarity, important, practical, ...
# 12225  [exploration, dimensional, fundamental, explor...
# 7771   [effectively, supervised, roadblock, aggregati...
# 13681  [dependences, structure, simplified, modificat...
# ...                                                  ...
# 21057  [technique, automatically, observing, dynamica...
# 18297  [hospitals, clinician, screening, procedure, t...
# 26183  [initially, segmented, segmentation, segmented...
# 22367  [multiplayer, environments, mastering, extensi...
# 19102  [decomposition, discussed, decomposition, deco...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5453     [selection, techniques, algorithms, determinis...
# 18446    [measuring, similarity, important, practical, ...
# 12225    [exploration, dimensional, fundamental, explor...
# 7771     [effectively, supervised, roadblock, aggregati...
# 13681    [dependences, structure, simplified, modificat...
#                                ...
# 6540     [stochastic, approximating, stochastic, approx...
# 9055     [recognition, activities, understanding, recog...
# 37586    [responses, hyperlink, enterprise, attachable,...
# 39007    [retrieval, extraction, techniques, directiona...
# 21792    [statistical, algorithmic, randomized, sketchi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8834 words.
# Out of those 4565 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="533596cb-96ba-42b3-b525-9e20885d22ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("533596cb-96ba-42b3-b525-9e20885d22ff")) {                    Plotly.newPlot(                        "533596cb-96ba-42b3-b525-9e20885d22ff",                        [{"x":["unsupervised","guarantees","resolving","techniques","competitive","generalization","algorithms","experiments","randomized","extensive","enclosing","selection","respectively","deterministic","preserved","comparable","supervised","demonstrate","important","calculation","neighbors","similarity","additional","desirable","illustrate","practical","empirically","knowledge","properties","iterative","principle","convergence","measuring","informative","information","constraints","efficient","constructing","theoretical","fundamental","predefined","sufficiently","exploratory","formalized","performance","synthetic","efficiently","exploration","interactive","identified","subjective","representation","dimensional","distribution","projections","construct","maximally","prototype","principled","visualizations","background","theoretic","intuitive","effective","algorithm","maximization","maintaining","interpreted","aggregation","effectively","expectation","significant","empirical","dependences","individual","parameters","attention","simplified","modifications","simplifying","evaluation","comparison","accuracies","structure","eliminating","regularizer","minimization","subgradient","comparing","optimization","ubiquitously","efficiency","functions","significantly","unsuitable","variables","explanations","anonymous","emotional","themselves","outperforms","consequences","explanation","available","technique","individuals","applications","messaging","corresponding","automatically","accurately","explaining","detection","detecting","combination","isotropic","gaussians","understood","statistically","investigated","complexity","separation","statistical","clustering","determine","computationally","procedure","dimensions","predicting","according","syntactic","embedding","resources","investigate","monolingual","translation","retrieval","exploiting","recognizing","beneficial","bilingual","displaying","alignments","extraction","stability","extrinsic","paragraphs","intensive","semantically","continuous","furthermore","embeddings","respective","applicable","languages","sentences","requiring","plagiarism","virtually","experimental","different","graphology","formulation","particular","independent","improvement","verification","exploring","convolutional","particularly","advancements","obtaining","forgeries","literature","handwritten","analyzing","architectures","descriptors","extractors","appearance","classifier","vulnerable","separating","signatures","handcrafted","published","signature","facilitating","conventional","correlation","arbitrary","generation","annotator","automatic","annotation","convenience","captioning","annotated","management","recurrent"],"y":[153,60,7,377,120,101,583,596,26,162,1,162,77,26,16,94,218,566,347,18,23,154,119,32,64,142,72,332,225,70,54,121,29,32,685,152,394,47,161,80,15,29,4,8,904,137,165,61,32,37,23,396,174,188,23,84,5,14,18,4,79,53,32,265,818,32,42,24,32,111,24,245,150,1,115,253,179,28,18,10,248,132,23,352,17,18,59,2,80,292,1,169,192,268,5,134,18,6,14,26,275,17,26,294,245,36,426,2,148,177,69,12,333,82,127,4,8,22,16,56,231,24,151,142,67,95,131,41,86,99,51,105,71,149,9,132,107,81,46,26,12,5,10,127,31,13,5,29,42,108,171,65,19,47,94,68,60,3,8,406,740,2,83,266,137,130,36,46,404,76,10,35,4,133,36,61,118,41,8,66,169,16,8,4,9,41,6,5,91,79,90,146,6,155,53,3,20,75,37,159],"type":"bar"},{"x":["unsupervised","guarantees","resolving","techniques","competitive","generalization","algorithm ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4565,), (4565, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>normative</span> <span style=''>data</span> <span style=''>in</span> <span style=''>speech</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.46938775510204084);'>assessment</span> <br/><br/><span style=''>Data</span> <span style=''>sets</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>Alzheimers</span> <span style=''>disease</span> <span style=''>(AD)</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>sparse</span> <span style=''>which</span> <span style=''>limits</span> <span style=''>their</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>train</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>generalizable</span> <span style=''>models</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>augment</span> <span style=''>such</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>DementiaBank</span> <span style=''>with</span> <span style=''>each</span> <span style=''>of</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>normative</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>the</span> <span style=''>Wisconsin</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Longitudinal</span> <span style=''>Study</span> <span style=''>and</span> <span style=''>Talk2Me</span> <span style=''>each</span> <span style=''>of</span> <span style=''>which</span> <span style=''>employs</span> <span style=''>a</span> <span style=''>speech</span> <span style=''>based</span> <span style=''>picture</span> <span style='background-color:rgba(0, 255, 0, 0.49056603773584906);'>description</span> <span style='background-color:rgba(0, 255, 0, 0.46938775510204084);'>assessment</span> <span style=''>Through</span> <span style=''>minority</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>oversampling</span> <span style=''>with</span> <span style=''>ADASYN</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperform</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style=''>in</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>people</span> <span style=''>with</span> <span style=''>and</span> <span style=''>without</span> <span style=''>AD</span> <span style=''>in</span> <span style=''>DementiaBank</span> <span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>highlights</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.32903225806451614);'>effectiveness</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.45238095238095233);'>combining</span> <span style=''>sparse</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>acquire</span> <span style=''>patient</span> <span style=''>data</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>large</span> <span style=''>and</span> <span style=''>easily</span> <span style='background-color:rgba(0, 255, 0, 0.4782608695652174);'>accessible</span> <span style='background-color:rgba(0, 255, 0, 0.42857142857142 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Near</span> <span style=''>Linear</span> <span style=''>Time</span> <span style=''>Local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Polynomial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>Local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>(Fan</span> <span style=''>Gijbels</span> <span style=''>1996)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>class</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problems</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforward</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratic</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>which</span> <span style=''>hinders</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicability</span> <span style=''>in</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>by</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>binary</span> <span style=''>indexed</span> <span style=''>trees</span> <span style=''>(Fenwick</span> <span style=''>1994)</span> <span style=''>Both</span> <span style=''>time</span> <span style=''>and</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexities</span> <span style=''>of</span> <span style=''>our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>are</span> <span style=''>nearly</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>inputs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Simulation</span> <span style=''>results</span> <span style=''>confirm</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style=''>approach</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Direction</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discrimination</span> <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretic</span> <span style=''>Analysis</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538464);'>Disparate</span> <span style=''>Impact</span> <span style=''>in</span> <span style=''>Machine</span> <span style=''>Learning</span> <br/><br/><span style=''>In</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538464);'>disparate</span> <span style=''>impact</span> <span style=''>refers</span> <span style=''>to</span> <span style=''>a</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>whereby</span> <span style=''>the</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.30627306273062727);'>distribution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>model</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>the</span> <span style=''>value</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style='background-color:rgba(0, 255, 0, 0.6170212765957446);'>attribute</span> <span style=''>(eg</span> <span style=''>race</span> <span style=''>or</span> <span style=''>gender)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>analyze</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538464);'>disparate</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>a</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>model</span> <span style=''>We</span> <span style=''>view</span> <span style=''>the</span> <span style=''>model</span> <span style=''>as</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>channel</span> <span style=''>and</span> <span style=''>quantify</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538464);'>disparate</span> <span style=''>impact</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4666666666666666);'>divergence</span> <span style=''>in</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.32121212121212117);'>distributions</span> <span style=''>over</span> <span style=''>two</span> <span style=''>groups</span> <span style=''>We</span> <span style=''>then</span> <span style=''>aim</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>textitcorrection</span> <span style=''>function</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>perturb</span> <span style=''>the</span> <span style=''>input</span> <span style='background-color:rgba(255, 0, 0, 0.32121212121212117);'>distributions</span> <span style=''>of</span> <span style=''>each</span> <span style=''>group</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discriminant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <span style=''>Based</span> <span style=''>On</span> <span style=''>Sampled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style=''>Distance</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Modulation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>letter</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modulation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>sampled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>distance</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifies</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constellations</span> <span style=''>using</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>approach</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>distance</span> <span style=''>at</span> <span style=''>specific</span> <span style=''>testpoints</span> <span style=''>along</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cumulative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>function</span> <span style=''>This</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>decision</span> <span style=''>criteria</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotically</span> <span style=''>provides</span> <span style=''>the</span> <span style=''>minimum</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>error</span> <span style=''>possible</span> <span style=''>given</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>testpoints</span> <span style=''>Testpoint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>locations</span> <span style=''>are</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimized</span> <span style=''>to</span> <span style=''>improve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>The</span> <span style=''>method</span> <span style=''>provides</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>gains</span> <span style=''>over</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>that</span> <span style=''>also</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>features</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.04865831842576029)
# 	segmentation (0.07370304114490162)
# 	information (0.24508050089445438)
# 	architecture (0.09481216457960644)
# 	experimental (0.14525939177101968)
# 	representation (0.14168157423971378)
# 	detection (0.11914132379248658)
# 	different (0.26475849731663686)
# 	recognition (0.14239713774597496)
# 	convolutional (0.1445438282647585)
#
# Some Statistics words are:
# 	variables (0.13915211970074812)
# 	theoretical (0.15311720698254364)
# 	estimation (0.171072319201995)
# 	algorithm (0.3940149625935162)
# 	statistical (0.15561097256857856)
# 	stochastic (0.14962593516209477)
# 	distribution (0.1765586034912718)
# 	inference (0.19052369077306733)
# 	dimensional (0.1825436408977556)
# 	regression (0.17556109725685787)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fb739966-c1b3-4631-b094-1e74bc3dd1f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb739966-c1b3-4631-b094-1e74bc3dd1f4")) {                    Plotly.newPlot(                        "fb739966-c1b3-4631-b094-1e74bc3dd1f4",                        [{"x":["unsupervised","guarantees","resolving","techniques","competitive","generalization","algorithms","experiments","randomized","extensive","enclosing","selection","respectively","deterministic","preserved","comparable","supervised","demonstrate","important","calculation","neighbors","similarity","additional","desirable","illustrate","practical","empirically","knowledge","properties","iterative","principle","convergence","measuring","informative","information","constraints","efficient","constructing","theoretical","fundamental","predefined","sufficiently","exploratory","formalized","performance","synthetic","efficiently","exploration","interactive","identified","subjective","representation","dimensional","distribution","projections","construct","maximally","prototype","principled","visualizations","background","theoretic","intuitive","effective","algorithm","maximization","maintaining","interpreted","aggregation","effectively","expectation","significant","empirical","dependences","individual","parameters","attention","simplified","modifications","simplifying","evaluation","comparison","accuracies","structure","eliminating","regularizer","minimization","subgradient","comparing","optimization","ubiquitously","efficiency","functions","significantly","unsuitable","variables","explanations","anonymous","emotional","themselves","outperforms","consequences","explanation","available","technique","individuals","applications","messaging","corresponding","automatically","accurately","explaining","detection","detecting","combination","isotropic","gaussians","understood","statistically","investigated","complexity","separation","statistical","clustering","determine","computationally","procedure","dimensions","predicting","according","syntactic","embedding","resources","investigate","monolingual","translation","retrieval","exploiting","recognizing","beneficial","bilingual","displaying","alignments","extraction","stability","extrinsic","paragraphs","intensive","semantically","continuous","furthermore","embeddings","respective","applicable","languages","sentences","requiring","plagiarism","virtually","experimental","different","graphology","formulation","particular","independent","improvement","verification","exploring","convolutional","particularly","advancements","obtaining","forgeries","literature","handwritten","analyzing","architectures","descriptors","extractors","appearance","classifier","vulnerable","separating","signatures","handcrafted","published","signature","facilitating","conventional","correlation","arbitrary","generation","annotator","automatic","annotation","convenience","captioning","annotated","management","recurrent","distributions","eigenvector","eigenvectors","illustrated","precision","theoretically","principal","estimation","assumption","simulation","established","consistency","semiparametric","multivariate","challenges","convenient","nonparanormal","satisfying","numerically","conditions","component","graphical","dependency","annotations","strategies","neglected","communicative","establish","coordinate","quadratic","stochastic","activations","minimizers","lojasiewicz","nonconvex","backpropagation","successfully","artificial","recognize","recognition","especially","handwriting","translating","traditional","specifies","communication","extracting","considered","successful","unconstrained","recognizes","weaknesses","demonstrated","arguments","introduced","discussed","po ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonparanormal
# 	exchangeable
# 	sparsistent
# 	nonstationary
# 	unconditional
# 	geostatistical
# 	normalised
# 	prognostic
# 	lauritzen
# 	inhibited
# 	idealized
# 	integrality
# 	robustification
# 	hypernetworks
# 	hypernetwork
# 	isometric
# 	misclassify
# 	bernsteins
# 	elliptical
# 	universality
# Some words which never appear in Statistics papers:
# 	messaging
# 	monolingual
# 	bilingual
# 	paragraphs
# 	plagiarism
# 	graphology
# 	forgeries
# 	convenience
# 	neglected
# 	communicative
# 	organised
# 	monocular
# 	collisions
# 	assemblies
# 	neuromorphic
# 	reconfigurable
# 	configured
# 	microsoft
# 	discontinuity
# 	dijkstras

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075503613716746e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
